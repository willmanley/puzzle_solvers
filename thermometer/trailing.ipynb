# %% [markdown]
# # <center> Thermometer Puzzles </center>

# %%
import numpy as np
from matplotlib import pyplot as plt

from testing.puzzle_specifications import thermometer_puzzle_specifications
from plotting import plot_puzzle

# %% [markdown]
# # <center> Plot an Example Puzzle </center>

# %%
# Choose a sample Thermometer Puzzle ID from the test data.
PUZZLE_ID = 9_682_815

# Plot the example puzzle.
plot_puzzle(**thermometer_puzzle_specifications[PUZZLE_ID])

# %% [markdown]
# # <center> Solve the Puzzle </center>
